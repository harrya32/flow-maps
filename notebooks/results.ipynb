# %%
import numpy as np

# %% [markdown]
# # Cite 100D

# %%
day_3_filtered_emd = [46.174,46.051,46.610]
day_3_filtered_mmd  = [0.022,0.022,0.023]
day_3_filtered_invalid = [16.578,14.840,17.513]

day_4_filtered_emd = [41.279,41.396,42.470]
day_4_filtered_mmd  = [0.011,0.011,0.012]
day_4_filtered_invalid = [15.909,17.246,15.374]

filtered_avg_emds = [(day_3_filtered_emd[i] + day_4_filtered_emd[i]) / 2 for i in range(len(day_3_filtered_emd))]
filtered_avg_mmds = [(day_3_filtered_mmd[i] + day_4_filtered_mmd[i]) / 2 for i in range(len(day_3_filtered_mmd))]
filtered_avg_invalids = [(day_3_filtered_invalid[i] + day_4_filtered_invalid[i]) / 2 for i in range(len(day_3_filtered_invalid))]

# %%
day_3_constrained_emd = [45.853,45.872,46.200]
day_3_constrained_mmd = [0.022,0.022,0.023]
day_3_constrained_invalid = [12.567,12.968,13.363]

day_4_constrained_emd = [41.508,42.168,42.161]
day_4_constrained_mmd = [0.010,0.010,0.011]
day_4_constrained_invalid = [12.433,15.374,12.268]

constrained_avg_emds = [(day_3_constrained_emd[i] + day_4_constrained_emd[i]) / 2 for i in range(len(day_3_constrained_emd))]
constrained_avg_mmds = [(day_3_constrained_mmd[i] + day_4_constrained_mmd[i]) / 2 for i in range(len(day_3_constrained_mmd))]
constrained_avg_invalids = [(day_3_constrained_invalid[i] + day_4_constrained_invalid[i]) / 2 for i in range(len(day_3_constrained_invalid))]

# %%
day_3_constrained_matching_emd = [46.039,46.324,45.937]
day_3_constrained_matching_mmd = [0.023,0.024,0.022]
day_3_constrained_matching_invalid = [18.316,18.181,16.444]

day_4_constrained_matching_emd = [43.279,40.384,41.026]
day_4_constrained_matching_mmd = [0.014,0.010,0.010]
day_4_constrained_matching_invalid = [15.642,15.775,16.176]

constrained_matching_avg_emds = [(day_3_constrained_matching_emd[i] + day_4_constrained_matching_emd[i]) / 2 for i in range(len(day_3_constrained_matching_emd))]
constrained_matching_avg_mmds = [(day_3_constrained_matching_mmd[i] + day_4_constrained_matching_mmd[i]) / 2 for i in range(len(day_3_constrained_matching_mmd))]
constrained_matching_avg_invalids = [(day_3_constrained_matching_invalid[i] + day_4_constrained_matching_invalid[i]) / 2 for i in range(len(day_3_constrained_matching_invalid))]

# %%
day_3_ot_emd = [45.923,45.277,45.323]
day_3_ot_mmd = [0.020, 0.020, 0.021]
day_3_ot_valid = [61.328,68.945,67.773]
day_3_ot_invalid = 100 - np.array(day_3_ot_valid)

day_4_ot_emd = [47.109,46.511,49.075]
day_4_ot_mmd = [0.018,0.016,0.020]
day_4_ot_valid = [69.140,70.703,65.234]
day_4_ot_invalid = 100 - np.array(day_4_ot_valid)

ot_avg_emds = [(day_3_ot_emd[i] + day_4_ot_emd[i]) / 2 for i in range(len(day_3_ot_emd))]
ot_avg_mmds = [(day_3_ot_mmd[i] + day_4_ot_mmd[i]) / 2 for i in range(len(day_3_ot_mmd))]
ot_avg_invalids = [(day_3_ot_invalid[i] + day_4_ot_invalid[i]) / 2 for i in range(len(day_3_ot_invalid))]

# %%
data = constrained_matching_avg_mmds

mean = np.mean(data)
std_error = np.std(data) / np.sqrt(len(data))
print(f"Mean: {mean}")
print(f"Standard Error: {std_error}")
# Out:
# Mean: 0.017166666666666667
# Standard Error: 0.0005931710140017392

# %% [markdown]
# # Multi 100D

# %%
day_3_filtered_emd = [49.482,48.900,48.700]
day_3_filtered_mmd  = [0.030,0.029,0.027]
day_3_filtered_invalid = [21.045,22.008,23.521]

day_4_filtered_emd = [59.714,58.084,57.839]
day_4_filtered_mmd  = [0.056,0.051,0.050]
day_4_filtered_invalid = [20.220,21.733,20.633]

filtered_avg_emds = [(day_3_filtered_emd[i] + day_4_filtered_emd[i]) / 2 for i in range(len(day_3_filtered_emd))]
filtered_avg_mmds = [(day_3_filtered_mmd[i] + day_4_filtered_mmd[i]) / 2 for i in range(len(day_3_filtered_mmd))]
filtered_avg_invalids = [(day_3_filtered_invalid[i] + day_4_filtered_invalid[i]) / 2 for i in range(len(day_3_filtered_invalid))]

# %%
day_3_constrained_emd = [49.130,48.882,48.729]
day_3_constrained_mmd = [0.030,0.029,0.027]
day_3_constrained_invalid = [18.569,18.707,18.982]

day_4_constrained_emd = [59.739,57.977,57.702]
day_4_constrained_mmd = [0.056,0.050,0.050]
day_4_constrained_invalid = [18.432,19.807,19.395]

constrained_avg_emds = [(day_3_constrained_emd[i] + day_4_constrained_emd[i]) / 2 for i in range(len(day_3_constrained_emd))]
constrained_avg_mmds = [(day_3_constrained_mmd[i] + day_4_constrained_mmd[i]) / 2 for i in range(len(day_3_constrained_mmd))]
constrained_avg_invalids = [(day_3_constrained_invalid[i] + day_4_constrained_invalid[i]) / 2 for i in range(len(day_3_constrained_invalid))]

# %%
day_3_constrained_matching_emd = [49.034, 49.264, 48.657]
day_3_constrained_matching_mmd = [0.030, 0.030, 0.028]
day_3_constrained_matching_invalid = [20.770, 21.733, 20.495]

day_4_constrained_matching_emd = [58.993, 56.876, 58.259]
day_4_constrained_matching_mmd = [0.052, 0.050, 0.052]
day_4_constrained_matching_invalid = [22.146, 22.283, 19.945]

constrained_matching_avg_emds = [(day_3_constrained_matching_emd[i] + day_4_constrained_matching_emd[i]) / 2 for i in range(len(day_3_constrained_matching_emd))]
constrained_matching_avg_mmds = [(day_3_constrained_matching_mmd[i] + day_4_constrained_matching_mmd[i]) / 2 for i in range(len(day_3_constrained_matching_mmd))]
constrained_matching_avg_invalids = [(day_3_constrained_matching_invalid[i] + day_4_constrained_matching_invalid[i]) / 2 for i in range(len(day_3_constrained_matching_invalid))]

# %%
day_3_ot_emd = [48.838,49.311,49.218]
day_3_ot_mmd = [0.028,0.030,0.028]
day_3_ot_valid = [65.820,66.797,66.797]
day_3_ot_invalid = 100 - np.array(day_3_ot_valid)

day_4_ot_emd = [59.225,60.819,61.959]
day_4_ot_mmd = [0.054,0.058,0.055]
day_4_ot_valid = [65.625,65.625,65.820]
day_4_ot_invalid = 100 - np.array(day_4_ot_valid)

ot_avg_emds = [(day_3_ot_emd[i] + day_4_ot_emd[i]) / 2 for i in range(len(day_3_ot_emd))]
ot_avg_mmds = [(day_3_ot_mmd[i] + day_4_ot_mmd[i]) / 2 for i in range(len(day_3_ot_mmd))]
ot_avg_invalids = [(day_3_ot_invalid[i] + day_4_ot_invalid[i]) / 2 for i in range(len(day_3_ot_invalid))]

# %%
data = constrained_matching_avg_mmds

mean = np.mean(data)
std_error = np.std(data) / np.sqrt(len(data))
print(f"Mean: {mean}")
print(f"Standard Error: {std_error}")
# Out:
# Mean: 0.04033333333333333
# Standard Error: 0.000272165526975907

# %% [markdown]
# Maizels

# %%
#ot-mfm
euler_emd = {
    "D3p2": [8.280260, 8.511993, 8.340159, 8.795464, 8.544215],
    "D3p4": [7.307663, 7.225769, 7.355688, 7.045629, 7.114639],
    "D3p6": [6.304421, 6.062361, 6.389088, 5.985370, 6.208999],
    "D4":    [9.621081, 9.704583, 9.754938, 9.599279, 9.452273],
    "D5":    [13.761897, 13.838956, 13.920686, 13.861991, 13.226612],
    "D6":    [13.365478, 13.339696, 13.805132, 13.830063, 13.006561],
    "D7":    [11.412014, 12.278191, 13.003776, 12.610968, 11.677925],
}

# %%
# get the mean and s.e. for each day

for day, emds in euler_emd.items():
    mean = np.mean(emds)
    std_error = np.std(emds) / np.sqrt(len(emds))
    print(f"{day} - Mean: {mean}, Standard Error: {std_error}")
# Out:
# D3p2 - Mean: 8.494418200000002, Standard Error: 0.08076553819415815
# D3p4 - Mean: 7.209877599999999, Standard Error: 0.05181628598315392
# D3p6 - Mean: 6.1900478, Standard Error: 0.06670960913775467
# D4 - Mean: 9.626430799999998, Standard Error: 0.04635456686058011
# D5 - Mean: 13.722028400000003, Standard Error: 0.11309347456563537
# D6 - Mean: 13.469386, Standard Error: 0.1392316952470236
# D7 - Mean: 12.1965748, Standard Error: 0.2618770680702532

# %%
#ot-flowmap

flowmap_emd = {
    "D3p2": [8.634367, 8.617196, 8.766264, 8.653576],
    "D3p4": [7.359656, 7.422230, 7.598420, 7.521722],
    "D3p6": [6.324116, 6.429880, 6.677159, 6.539226],
    "D4":    [9.199967, 9.166632, 9.220897, 9.067312],
    "D5":    [14.598145, 14.476023, 14.571227, 14.226192],
    "D6":    [14.448201, 14.283269, 14.340940, 13.725524],
    "D7":    [11.936086, 11.639086, 11.825768, 11.022750],
}

# %%
for day, emds in flowmap_emd.items():
    mean = np.mean(emds)
    std_error = np.std(emds) / np.sqrt(len(emds))
    print(f"{day} - Mean: {mean}, Standard Error: {std_error}")
# Out:
# D3p2 - Mean: 8.66785075, Standard Error: 0.029129024909390216
# D3p4 - Mean: 7.475507, Standard Error: 0.0457597836014332
# D3p6 - Mean: 6.49259525, Standard Error: 0.06545831923958839
# D4 - Mean: 9.163702, Standard Error: 0.029459755652839505
# D5 - Mean: 14.46789675, Standard Error: 0.07336934360853252
# D6 - Mean: 14.199483500000001, Standard Error: 0.1399839173461097
# D7 - Mean: 11.605922500000002, Standard Error: 0.1765166357406221

# %%
#ours
flowmap_emd = {
    "D3p2": [8.690831, 8.614968, 8.655093],
    "D3p4": [7.466147, 7.448310, 7.501310],
    "D3p6": [6.521731, 6.517299, 6.613445],
    "D4":    [9.201134, 9.045533, 9.183473],
    "D5":    [14.553126, 14.244590, 14.504313],
    "D6":    [14.017781, 13.797097, 14.062498],
    "D7":    [11.004174, 10.886088, 11.231051],
}

# %%
for day, emds in flowmap_emd.items():
    mean = np.mean(emds)
    std_error = np.std(emds) / np.sqrt(len(emds))
    print(f"{day} - Mean: {mean}, Standard Error: {std_error}")
# Out:
# D3p2 - Mean: 8.653630666666666, Standard Error: 0.017891043732880776
# D3p4 - Mean: 7.471922333333334, Standard Error: 0.012712774470615773
# D3p6 - Mean: 6.550825, Standard Error: 0.025585842248312778
# D4 - Mean: 9.14338, Standard Error: 0.04016218311629289
# D5 - Mean: 14.434009666666668, Standard Error: 0.07818146246938493
# D6 - Mean: 13.959125333333333, Standard Error: 0.06698223333978302
# D7 - Mean: 11.040437666666667, Standard Error: 0.08264537088916357

# %%
# constrained flow match
euler_emd = {
    "D3p2": [8.583338, 8.613939, 8.624949],
    "D3p4": [7.402354, 7.395922, 7.396494],
    "D3p6": [6.450786, 6.388240, 6.415597],
    "D4":    [9.142395, 9.148712, 9.186098],
    "D5":    [14.360699, 14.361636, 14.555445],
    "D6":    [13.940703, 13.786623, 14.163958],
    "D7":    [11.252924, 10.957715, 11.463339],
}

# %%
for day, emds in euler_emd.items():
    mean = np.mean(emds)
    std_error = np.std(emds) / np.sqrt(len(emds))
    print(f"{day} - Mean: {mean}, Standard Error: {std_error}")
# Out:
# D3p2 - Mean: 8.607408666666666, Standard Error: 0.010163691043594162
# D3p4 - Mean: 7.398256666666666, Standard Error: 0.0016781538357065141
# D3p6 - Mean: 6.418207666666667, Standard Error: 0.01478070975843056
# D4 - Mean: 9.159068333333332, Standard Error: 0.011134813098599192
# D5 - Mean: 14.425926666666667, Standard Error: 0.05287609939877972
# D6 - Mean: 13.963761333333332, Standard Error: 0.08943550203400226
# D7 - Mean: 11.224659333333333, Standard Error: 0.1197340347792493

# %%
#bio prior map
flowmap_emd = {
    "D3p2": [8.669271, 8.663551, 8.636215],
    "D3p4": [7.426622, 7.494234, 7.356462],
    "D3p6": [6.463629, 6.561945, 6.330400],
    "D4":    [9.201480, 9.175263, 9.152713],
    "D5":    [14.487186, 14.327004, 14.329915],
    "D6":    [13.915787, 13.805869, 13.785748],
    "D7":    [11.019686, 11.005116, 10.929331],
}

# %%
for day, emds in flowmap_emd.items():
    mean = np.mean(emds)
    std_error = np.std(emds) / np.sqrt(len(emds))
    print(f"{day} - Mean: {mean}, Standard Error: {std_error}")
# Out:
# D3p2 - Mean: 8.656345666666667, Standard Error: 0.008328163801000609
# D3p4 - Mean: 7.425772666666667, Standard Error: 0.03247502295383103
# D3p6 - Mean: 6.451991333333333, Standard Error: 0.0547820899774396
# D4 - Mean: 9.176485333333332, Standard Error: 0.01150531902434048
# D5 - Mean: 14.381368333333333, Standard Error: 0.043205329954977806
# D6 - Mean: 13.835801333333334, Standard Error: 0.03299661199555476
# D7 - Mean: 10.984710999999999, Standard Error: 0.022868122038233907
